# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import requests
import json
import os
import glob
import plotly.express as px

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# import dataset
df = pd.read_csv('../Resources/gun_law_provisions_by_state_2016.csv')
df.head(5)
# Out:
#         state  deaths_per_capita  felony  invcommitment  invoutpatient  \
# 0     Alabama               21.5       0              1              0
# 1      Alaska               23.3       1              0              0
# 2     Arizona               15.2       1              1              1
# 3    Arkansas               17.8       1              1              0
# 4  California                7.9       1              1              0
#
#    danger  drugmisdemeanor  alctreatment  alcoholism  relinquishment  ...  \
# 0       1                0             0           1               0  ...
# 1       0                0             0           0               0  ...
# 2       1                0             0           0               0  ...
# 3       1                0             0           0               0  ...
# 4       1                0             0           1               0  ...
#
#    expartedating  dvrosurrender  dvrosurrendernoconditions  \
# 0              0              0                          0
# 1              0              0                          0
# 2              0              0                          0
# 3              0              0                          0
# 4              1              1                          1
#
#    dvrosurrenderdating  expartesurrender  expartesurrendernoconditions  \
# 0                    0                 0                             0
# 1                    0                 0                             0
# 2                    0                 0                             0
# 3                    0                 0                             0
# 4                    1                 1                             1
#
#    expartesurrenderdating  dvroremoval  stalking  lawtotal
# 0                       0            0         0        10
# 1                       0            0         0         3
# 2                       0            0         1         8
# 3                       0            0         0        11
# 4                       1            1         1       104
#
# [5 rows x 137 columns]

# %%
# set index
df = df.set_index('state')

df.head(5)
# Out:
#             deaths_per_capita  felony  invcommitment  invoutpatient  danger  \
# state
# Alabama                  21.5       0              1              0       1
# Alaska                   23.3       1              0              0       0
# Arizona                  15.2       1              1              1       1
# Arkansas                 17.8       1              1              0       1
# California                7.9       1              1              0       1
#
#             drugmisdemeanor  alctreatment  alcoholism  relinquishment  \
# state
# Alabama                   0             0           1               0
# Alaska                    0             0           0               0
# Arizona                   0             0           0               0
# Arkansas                  0             0           0               0
# California                0             0           1               0
#
#             violent  ...  expartedating  dvrosurrender  \
# state                ...
# Alabama           0  ...              0              0
# Alaska            0  ...              0              0
# Arizona           0  ...              0              0
# Arkansas          0  ...              0              0
# California        1  ...              1              1
#
#             dvrosurrendernoconditions  dvrosurrenderdating  expartesurrender  \
# state
# Alabama                             0                    0                 0
# Alaska                              0                    0                 0
# Arizona                             0                    0                 0
# Arkansas                            0                    0                 0
# California                          1                    1                 1
#
#             expartesurrendernoconditions  expartesurrenderdating  dvroremoval  \
# state
# Alabama                                0                       0            0
# Alaska                                 0                       0            0
# Arizona                                0                       0            0
# Arkansas                               0                       0            0
# California                             1                       1            1
#
#             stalking  lawtotal
# state
# Alabama            0        10
# Alaska             0         3
# Arizona            1         8
# Arkansas           0        11
# California         1       104
#
# [5 rows x 136 columns]

# %%
# import data on laws, # of states with law applicable and average deaths by states with law
df2 = pd.read_csv('../Resources/gun_laws_average_deaths_by_law.csv', encoding = "ISO-8859-1")
df2.head(5)
# Out:
#                law_tag        Variable_Name  Average_deaths_per_capita  \
# 0               felony               felony                      12.85
# 1  age18longgunpossess  age18longgunpossess                       9.92
# 2     age18longgunsale     age18longgunsale                      11.77
# 3  age21handgunpossess  age21handgunpossess                       5.95
# 4     age21handgunsale     age21handgunsale                       8.81
#
#    number_of_states_with_law                                   Category  \
# 0                         37  Prohibitions for high-risk gun possession
# 1                         12                     Possession regulations
# 2                         20                          Buyer regulations
# 3                          8                     Possession regulations
# 4                         14                          Buyer regulations
#
#        Sub-Category                     Brief_Description_of_Provision
# 0            Felony  Firearm possession is prohibited for all peopl...
# 1  Age restrictions            No possession of long guns until age 18
# 2  Age restrictions  Purchase of long guns from licensed dealers an...
# 3  Age restrictions             No possession of handguns until age 21
# 4  Age restrictions  Purchase of handguns from licensed dealers and...

# %%
# drop rows where 3 or less states have law
df2 = df2[df2['number_of_states_with_law'] > 3]
df2.sample(5)
# Out:
#                                     law_tag              Variable_Name  \
# 2                          age18longgunsale           age18longgunsale
# 46  domestic_violence_surrendernoconditions  dvrosurrendernoconditions
# 34             college_campas_ban_concealed           collegeconcealed
# 36                                   dealer                     dealer
# 42                 domestic_violence_dating                 dvrodating
#
#     Average_deaths_per_capita  number_of_states_with_law  \
# 2                       11.77                         20
# 46                       9.37                         13
# 34                      11.90                         12
# 36                       6.63                          7
# 42                       9.86                         16
#
#                   Category       Sub-Category  \
# 2        Buyer regulations   Age restrictions
# 46       Domestic violence  Restraining order
# 34  Possession regulations       Campus carry
# 36      Dealer regulations          Licensing
# 42       Domestic violence  Restraining order
#
#                        Brief_Description_of_Provision
# 2   Purchase of long guns from licensed dealers an...
# 46  No additional finding is required before the f...
# 34  No gun carrying on college campuses, including...
# 36  State dealer license required for sale of all ...
# 42  DVROs are automatically prohibiting if the sub...

# %%
# Importing the dataset for ML
ml_df = df[['lawtotal', 'deaths_per_capita']].copy()
X = ml_df.iloc[:, :-1].values
y = ml_df.iloc[:, 1].values
ml_df
# Out:
#                 lawtotal  deaths_per_capita
# state
# Alabama               10               21.5
# Alaska                 3               23.3
# Arizona                8               15.2
# Arkansas              11               17.8
# California           104                7.9
# Colorado              30               14.3
# Connecticut           88                4.6
# Delaware              38               11.0
# Florida               21               12.6
# Georgia                6               15.0
# Hawaii                79                4.5
# Idaho                  2               14.6
# Illinois              65               11.7
# Indiana               12               15.0
# Iowa                  25                9.2
# Kansas                 4               13.4
# Kentucky               7               17.5
# Louisiana             12               21.3
# Maine                 11                8.3
# Maryland              64               11.9
# Massachusetts        101                3.4
# Michigan              21               12.3
# Minnesota             41                7.6
# Mississippi            2               19.9
# Missouri               7               19.0
# Montana                4               18.9
# Nebraska              22                9.1
# Nevada                15               16.8
# New Hampshire         10                9.3
# New Jersey            67                5.5
# New Mexico            10               18.1
# New York              74                4.4
# North Carolina        30               13.7
# North Dakota          14               11.9
# Ohio                  16               12.9
# Oklahoma               9               19.6
# Oregon                35               11.9
# Pennsylvania          37               12.0
# Rhode Island          42                4.1
# South Carolina        12               17.7
# South Dakota           5               13.4
# Tennessee             22               17.1
# Texas                 18               12.1
# Utah                  11               12.9
# Vermont                6               11.1
# Virginia              13               12.1
# Washington            43                9.0
# West Virginia         18               17.5
# Wisconsin             23               11.4
# Wyoming                8               17.4

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 0)

# %%
# Fitting Simple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predicting the Test set results
y_pred = regressor.predict(X_test)

# %%
# Saving model to disk
pickle.dump(regressor, open('model.pkl','wb'))

# %%
# Loading model to compare the results
model = pickle.load( open('model.pkl','rb'))
print(model.predict([[60]]))
# Out:
# [9.09755953]
